# %% [markdown]
# ## Imports

# %%
import os
import pandas as pd
import geopandas as gpd
from zipfile import ZipFile

from pathlib import Path
from sqlalchemy import create_engine, text
from geoalchemy2 import Geometry

# %%
DATA_DIR = Path("../data/JC")

citibike_path = DATA_DIR / "JC2025.csv"
weather_path = DATA_DIR / "jersey_weather_2025.csv"
neighborhood_path = DATA_DIR / "jersey-city-neighborhoods.geojson"

# %% [markdown]
# ## Database Connection

# %%
DB_USER = os.getenv("DB_USER")
DB_PASSWORD = os.getenv("DB_PASSWORD")
DB_HOST = os.getenv("DB_HOST", "localhost")
DB_PORT = os.getenv("DB_PORT", "5432")
DB_NAME = os.getenv("DB_NAME")

DATABASE_URL = (
    f"postgresql+psycopg2://{DB_USER}:{DB_PASSWORD}"
    f"@{DB_HOST}:{DB_PORT}/{DB_NAME}"
)


DATABASE_URL
# Out:
# 'postgresql+psycopg2://postgres:password@localhost:5432/citibike'

# %%
## Engine Creation
engine = create_engine(DATABASE_URL)

engine
# Out:
# Engine(postgresql+psycopg2://postgres:***@localhost:5432/citibike)

# %% [markdown]
# ### Test Connection

# %%
with engine.connect() as connection:
    result = connection.execute(text("SELECT version();"))
    print(result.fetchone()[0])
# Out:
# PostgreSQL 17.0 (Debian 17.0-1.pgdg110+1) on x86_64-pc-linux-gnu, compiled by gcc (Debian 10.2.1-6) 10.2.1 20210110, 64-bit

# %% [markdown]
# ### Test PostGIS Extension

# %%
with engine.connect() as connection:
    result = connection.execute(text("SELECT PostGIS_Version();"))
    print(result.fetchone()[0])
# Out:
# 3.4 USE_GEOS=1 USE_PROJ=1 USE_STATS=1

# %% [markdown]
# ## Citibike to PostgreSQL

# %% [markdown]
# ### Reading the data

# %%
citibike_df = pd.read_csv(citibike_path)

citibike_df.head()
# Out:
#             ride_id  rideable_type               started_at  \
# 0  9F734BE1BFC45FF4  electric_bike  2025-11-18 18:34:14.943
# 1  B6C773B13AC0E465   classic_bike  2025-11-26 16:29:15.513
# 2  C300465AA158280F  electric_bike  2025-11-04 22:31:58.010
# 3  31A424FC97C8AAFB   classic_bike  2025-11-08 06:51:57.424
# 4  08C5EA04CB1FDC57   classic_bike  2025-11-24 20:31:21.758
#
#                   ended_at     start_station_name start_station_id  \
# 0  2025-11-18 18:47:33.391           Glenwood Ave            JC094
# 1  2025-11-26 16:43:45.235           Glenwood Ave            JC094
# 2  2025-11-04 22:38:57.017  Bloomfield St & 15 St            HB203
# 3  2025-11-08 06:57:45.627      Clinton St & 7 St            HB303
# 4  2025-11-24 20:38:01.261      Clinton St & 7 St            HB303
#
#                end_station_name end_station_id  start_lat  start_lng  \
# 0  West Side Ave & Stegman Pkwy          JC131  40.727551 -74.071061
# 1  West Side Ave & Stegman Pkwy          JC131  40.727551 -74.071061
# 2            Marshall St & 2 St          HB408  40.754530 -74.026580
# 3            Marshall St & 2 St          HB408  40.745420 -74.033320
# 4            Marshall St & 2 St          HB408  40.745420 -74.033320
#
#      end_lat    end_lng member_casual
# 0  40.710870 -74.093680        member
# 1  40.710870 -74.093680        member
# 2  40.740802 -74.042521        member
# 3  40.740802 -74.042521        member
# 4  40.740802 -74.042521        member

# %%
print(citibike_df.columns)
citibike_df.info()
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual'],
#       dtype='str')
# <class 'pandas.DataFrame'>
# RangeIndex: 1002704 entries, 0 to 1002703
# Data columns (total 13 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   ride_id             1002704 non-null  str
#  1   rideable_type       1002704 non-null  str
#  2   started_at          1002704 non-null  str
#  3   ended_at            1002704 non-null  str
#  4   start_station_name  1002701 non-null  str
#  5   start_station_id    1002701 non-null  str
#  6   end_station_name    999469 non-null   str
#  7   end_station_id      998307 non-null   str
#  8   start_lat           1002702 non-null  float64
#  9   start_lng           1002702 non-null  float64
#  10  end_lat             999260 non-null   float64
#  11  end_lng             999260 non-null   float64
#  12  member_casual       1002704 non-null  str
# dtypes: float64(4), str(9)
# memory usage: 99.5 MB

# %%
# Cleaning the Data
citibike_df["started_at"] = pd.to_datetime(
    citibike_df["started_at"],
    errors="coerce"
)

citibike_df["ended_at"] = pd.to_datetime(
    citibike_df["ended_at"],
    errors="coerce"
)

# %%
citibike_df["ride_date"] = citibike_df["started_at"].dt.date

citibike_df["ride_date"] = pd.to_datetime(
    citibike_df["ride_date"],
    errors="coerce"
)

citibike_df[
    [
        "ride_id",
        "started_at",
        "ended_at",
        "ride_date"
    ]
].head()
# Out:
#             ride_id              started_at                ended_at  ride_date
# 0  9F734BE1BFC45FF4 2025-11-18 18:34:14.943 2025-11-18 18:47:33.391 2025-11-18
# 1  B6C773B13AC0E465 2025-11-26 16:29:15.513 2025-11-26 16:43:45.235 2025-11-26
# 2  C300465AA158280F 2025-11-04 22:31:58.010 2025-11-04 22:38:57.017 2025-11-04
# 3  31A424FC97C8AAFB 2025-11-08 06:51:57.424 2025-11-08 06:57:45.627 2025-11-08
# 4  08C5EA04CB1FDC57 2025-11-24 20:31:21.758 2025-11-24 20:38:01.261 2025-11-24

# %%
citibike_df.isna().sum()
# Out:
# ride_id                  0
# rideable_type            0
# started_at               0
# ended_at                 0
# start_station_name       3
# start_station_id         3
# end_station_name      3235
# end_station_id        4397
# start_lat                2
# start_lng                2
# end_lat               3444
# end_lng               3444
# member_casual            0
# ride_date                0
# dtype: int64

# %% [markdown]
# ### Writing CitiBike data to PostgreSQL Database

# %%
citibike_df.to_sql(
    name="jersey_city",
    con=engine,
    if_exists="replace",
    index=False,
    chunksize=50_000,
    method="multi"
)
# Out:
# 1002704

# %% [markdown]
# #### Check rows in Pandas

# %%
query = """
SELECT
    *
FROM jersey_city
LIMIT 10;
"""

pd.read_sql(
    query,
    con=engine
)
# Out:
#             ride_id  rideable_type              started_at  \
# 0  9F734BE1BFC45FF4  electric_bike 2025-11-18 18:34:14.943
# 1  B6C773B13AC0E465   classic_bike 2025-11-26 16:29:15.513
# 2  C300465AA158280F  electric_bike 2025-11-04 22:31:58.010
# 3  31A424FC97C8AAFB   classic_bike 2025-11-08 06:51:57.424
# 4  08C5EA04CB1FDC57   classic_bike 2025-11-24 20:31:21.758
# 5  FE738136C74EA7C0  electric_bike 2025-11-23 14:39:45.031
# 6  EFD5AB3E138908E4  electric_bike 2025-11-19 21:08:33.665
# 7  A45C71BC39881445  electric_bike 2025-11-11 15:29:51.785
# 8  33FE83F576FDA580  electric_bike 2025-11-08 13:11:03.012
# 9  29D92C83FFD009F2  electric_bike 2025-11-14 18:39:54.678
#
#                  ended_at     start_station_name start_station_id  \
# 0 2025-11-18 18:47:33.391           Glenwood Ave            JC094
# 1 2025-11-26 16:43:45.235           Glenwood Ave            JC094
# 2 2025-11-04 22:38:57.017  Bloomfield St & 15 St            HB203
# 3 2025-11-08 06:57:45.627      Clinton St & 7 St            HB303
# 4 2025-11-24 20:38:01.261      Clinton St & 7 St            HB303
# 5 2025-11-23 14:43:32.044      Clinton St & 7 St            HB303
# 6 2025-11-19 21:14:22.866      Clinton St & 7 St            HB303
# 7 2025-11-11 15:33:44.683      Clinton St & 7 St            HB303
# 8 2025-11-08 13:15:13.476      Clinton St & 7 St            HB303
# 9 2025-11-14 18:44:18.044      Clinton St & 7 St            HB303
#
#                end_station_name end_station_id  start_lat  start_lng  \
# 0  West Side Ave & Stegman Pkwy          JC131  40.727551 -74.071061
# 1  West Side Ave & Stegman Pkwy          JC131  40.727551 -74.071061
# 2            Marshall St & 2 St          HB408  40.754530 -74.026580
# 3            Marshall St & 2 St          HB408  40.745420 -74.033320
# 4            Marshall St & 2 St          HB408  40.745420 -74.033320
# 5            Marshall St & 2 St          HB408  40.745420 -74.033320
# 6            Marshall St & 2 St          HB408  40.745420 -74.033320
# 7            Marshall St & 2 St          HB408  40.745420 -74.033320
# 8            Marshall St & 2 St          HB408  40.745420 -74.033320
# 9            Marshall St & 2 St          HB408  40.745420 -74.033320
#
#      end_lat    end_lng member_casual  ride_date
# 0  40.710870 -74.093680        member 2025-11-18
# 1  40.710870 -74.093680        member 2025-11-26
# 2  40.740802 -74.042521        member 2025-11-04
# 3  40.740802 -74.042521        member 2025-11-08
# 4  40.740802 -74.042521        member 2025-11-24
# 5  40.740802 -74.042521        member 2025-11-23
# 6  40.740802 -74.042521        member 2025-11-19
# 7  40.740802 -74.042521        member 2025-11-11
# 8  40.740802 -74.042521        member 2025-11-08
# 9  40.740802 -74.042521        member 2025-11-14

# %% [markdown]
# ## Load Weather Data

# %%
weather_df = pd.read_csv(weather_path)

weather_df.head()
# Out:
#    2m_max  2m_min  2m_mean  precipitation_sum  rain_sum  snowfall_sum  \
# 0    10.9     3.9      7.4                4.5       4.5           0.0
# 1     5.4     0.3      2.6                0.0       0.0           0.0
# 2     3.2    -1.9      0.4                0.0       0.0           0.0
# 3    -0.1    -2.7     -1.4                0.0       0.0           0.0
# 4     0.3    -3.6     -2.2                0.0       0.0           0.0
#
#    wind_speed_10m_max        date
# 0                23.2  2025-01-01
# 1                25.1  2025-01-02
# 2                17.1  2025-01-03
# 3                26.1  2025-01-04
# 4                19.9  2025-01-05

# %% [markdown]
# ### Convert Date Column

# %%
weather_df["date"] = pd.to_datetime(
    weather_df["date"],
    errors="coerce"
)

weather_df = weather_df.rename(
    columns={
        "2m_max": "temp_max",
        "2m_min": "temp_min",
        "2m_mean": "temp_mean"
    }
)
weather_df.head()
# Out:
#    temp_max  temp_min  temp_mean  precipitation_sum  rain_sum  snowfall_sum  \
# 0      10.9       3.9        7.4                4.5       4.5           0.0
# 1       5.4       0.3        2.6                0.0       0.0           0.0
# 2       3.2      -1.9        0.4                0.0       0.0           0.0
# 3      -0.1      -2.7       -1.4                0.0       0.0           0.0
# 4       0.3      -3.6       -2.2                0.0       0.0           0.0
#
#    wind_speed_10m_max       date
# 0                23.2 2025-01-01
# 1                25.1 2025-01-02
# 2                17.1 2025-01-03
# 3                26.1 2025-01-04
# 4                19.9 2025-01-05

# %% [markdown]
# ### Write Weather Data to Database

# %%
#| echo: true

weather_df.to_sql(
    name="jersey_weather",
    con=engine,
    if_exists="replace",
    index=False
)
# Out:
# 365

# %%
query = """
SELECT
    *
FROM jersey_weather
LIMIT 10;
"""

pd.read_sql(
    query,
    con=engine
)
# Out:
#    temp_max  temp_min  temp_mean  precipitation_sum  rain_sum  snowfall_sum  \
# 0      10.9       3.9        7.4                4.5       4.5          0.00
# 1       5.4       0.3        2.6                0.0       0.0          0.00
# 2       3.2      -1.9        0.4                0.0       0.0          0.00
# 3      -0.1      -2.7       -1.4                0.0       0.0          0.00
# 4       0.3      -3.6       -2.2                0.0       0.0          0.00
# 5      -1.5      -4.4       -2.3                1.7       0.0          1.19
# 6      -3.0      -8.7       -5.2                0.0       0.0          0.00
# 7      -2.5      -6.6       -4.3                0.0       0.0          0.00
# 8      -1.5      -6.8       -4.2                0.0       0.0          0.00
# 9       3.3      -3.8       -0.9                0.0       0.0          0.00
#
#    wind_speed_10m_max       date
# 0                23.2 2025-01-01
# 1                25.1 2025-01-02
# 2                17.1 2025-01-03
# 3                26.1 2025-01-04
# 4                19.9 2025-01-05
# 5                16.7 2025-01-06
# 6                29.9 2025-01-07
# 7                25.4 2025-01-08
# 8                29.0 2025-01-09
# 9                22.5 2025-01-10

# %% [markdown]
# ## Load Neighborhood GeoJSON as Spatial Table

# %% [markdown]
# ### Read GeoJSON with GeoPandas

# %%
neighborhood_gdf = gpd.read_file(neighborhood_path)

neighborhood_gdf.head()
# Out:
#    cartodb_id   area_sq_ft     acres              area    neighborhood  color  \
# 0          38  411601381.8  9449.068        Greenville    Port Liberte    NaN
# 1          52  411601381.8  9449.068  Bergen-Lafayette  LSP Industrial    NaN
# 2          29  411601381.8  9449.068         West Side      Hackensack    NaN
# 3          35  411601381.8  9449.068  Bergen-Lafayette       Lafayette   12.0
# 4          51  411601381.8  9449.068        Greenville    Jackson Hill   15.0
#
#          lon        lat  area_sq_km  estimated_neighborhood_population  \
# 0 -74.074540  40.694202    38.23902                        5739.716981
# 1 -74.062358  40.699189    38.23902                        5739.716981
# 2 -74.085147  40.735520    38.23902                        5739.716981
# 3 -74.061279  40.712676    38.23902                        5739.716981
# 4 -74.085503  40.700791    38.23902                        5739.716981
#
#    population_density_per_sq_km  nbhd_population  \
# 0                     150.10105      5739.716981
# 1                     150.10105      5739.716981
# 2                     150.10105      5739.716981
# 3                     150.10105      5739.716981
# 4                     150.10105      5739.716981
#
#                                             geometry
# 0  POLYGON ((-74.06862 40.70098, -74.06808 40.696...
# 1  POLYGON ((-74.06808 40.69684, -74.06862 40.700...
# 2  POLYGON ((-74.07601 40.73822, -74.07781 40.737...
# 3  POLYGON ((-74.056 40.71735, -74.056 40.71692, ...
# 4  POLYGON ((-74.07561 40.70233, -74.0758 40.7020...

# %%
# Checking the crs of the GeoDataFrame
neighborhood_gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
neighborhood_gdf.geom_type.value_counts()
# Out:
# Polygon    53
# Name: count, dtype: int64

# %% [markdown]
# ### Write GeoDataFrame to PostGIS

# %%
#| echo: true

neighborhood_gdf.to_postgis(
    name="jersey_city_neighborhoods",
    con=engine,
    if_exists="replace",
    index=False
)

# %%
query = """
SELECT
    neighborhood,
    ST_GeometryType(geometry) AS geometry_type,
    ST_SRID(geometry) AS srid
FROM jersey_city_neighborhoods
LIMIT 5;
"""

pd.read_sql(
    query,
    con=engine
)
# Out:
#      neighborhood geometry_type  srid
# 0    Port Liberte    ST_Polygon  4326
# 1  LSP Industrial    ST_Polygon  4326
# 2      Hackensack    ST_Polygon  4326
# 3       Lafayette    ST_Polygon  4326
# 4    Jackson Hill    ST_Polygon  4326

# %% [markdown]
# ## Create Station Spatial Table
# ##### The ride table has start and end coordinates, but we also want a station-level spatial table.

# %% [markdown]
# ### Create Station Summary

# %%
start_stations = citibike_df[
    [
        "ride_id",
        "start_station_id",
        "start_station_name",
        "start_lat",
        "start_lng"
    ]
].copy()

start_stations = start_stations.rename(
    columns={
        "start_station_id": "station_id",
        "start_station_name": "station_name",
        "start_lat": "lat",
        "start_lng": "lng"
    }
)

start_stations["activity_type"] = "departure"

# %%
end_stations = citibike_df[
    [
        "ride_id",
        "end_station_id",
        "end_station_name",
        "end_lat",
        "end_lng"
    ]
].copy()

end_stations = end_stations.rename(
    columns={
        "end_station_id": "station_id",
        "end_station_name": "station_name",
        "end_lat": "lat",
        "end_lng": "lng"
    }
)

end_stations["activity_type"] = "arrival"

# %%
station_activity_long = pd.concat(
    [
        start_stations,
        end_stations
    ],
    ignore_index=True
)

station_activity_long = station_activity_long.dropna(
    subset=[
        "station_id",
        "station_name",
        "lat",
        "lng"
    ]
)

# %%
station_activity_agg = (
    station_activity_long
    .groupby(
        [
            "station_id",
            "station_name",
            "lat",
            "lng",
            "activity_type"
        ],
        as_index=False
    )
    .agg(
        number_of_rides=("ride_id", "count")
    )
)

# %%
station_summary = (
    station_activity_agg
    .pivot_table(
        index=[
            "station_id",
            "station_name",
            "lat",
            "lng"
        ],
        columns="activity_type",
        values="number_of_rides",
        fill_value=0
    )
    .reset_index()
)

station_summary.columns.name = None

station_summary = station_summary.rename(
    columns={
        "departure": "total_departures",
        "arrival": "total_arrivals"
    }
)

if "total_departures" not in station_summary.columns:
    station_summary["total_departures"] = 0

if "total_arrivals" not in station_summary.columns:
    station_summary["total_arrivals"] = 0

station_summary["total_activity"] = (
    station_summary["total_departures"] +
    station_summary["total_arrivals"]
)

station_summary["net_departures"] = (
    station_summary["total_departures"] -
    station_summary["total_arrivals"]
)

station_summary = station_summary.sort_values(
    "total_activity",
    ascending=False
).reset_index(drop=True)

station_summary.head()
# Out:
#   station_id                              station_name        lat        lng  \
# 0      JC115                             Grove St PATH  40.719410 -74.043090
# 1      HB101  Hoboken Terminal - Hudson St & Hudson Pl  40.735938 -74.030305
# 2      HB106                      River St & Newark St  40.736722 -74.029007
# 3      JC009                             Hamilton Park  40.727596 -74.044247
# 4      JC109                      Bergen Ave & Sip Ave  40.731009 -74.064437
#
#    total_arrivals  total_departures  total_activity  net_departures
# 0         67171.0           64280.0        131451.0         -2891.0
# 1         37663.0           36943.0         74606.0          -720.0
# 2         37333.0           36139.0         73472.0         -1194.0
# 3         31335.0           31305.0         62640.0           -30.0
# 4         30082.0           30430.0         60512.0           348.0

# %% [markdown]
# ### Convert Station Summary to GeoDataFrame

# %%
station_gdf = gpd.GeoDataFrame(
    station_summary,
    geometry=gpd.points_from_xy(
        station_summary["lng"],
        station_summary["lat"]
    ),
    crs="EPSG:4326"
)

station_gdf.head()
# Out:
#   station_id                              station_name        lat        lng  \
# 0      JC115                             Grove St PATH  40.719410 -74.043090
# 1      HB101  Hoboken Terminal - Hudson St & Hudson Pl  40.735938 -74.030305
# 2      HB106                      River St & Newark St  40.736722 -74.029007
# 3      JC009                             Hamilton Park  40.727596 -74.044247
# 4      JC109                      Bergen Ave & Sip Ave  40.731009 -74.064437
#
#    total_arrivals  total_departures  total_activity  net_departures  \
# 0         67171.0           64280.0        131451.0         -2891.0
# 1         37663.0           36943.0         74606.0          -720.0
# 2         37333.0           36139.0         73472.0         -1194.0
# 3         31335.0           31305.0         62640.0           -30.0
# 4         30082.0           30430.0         60512.0           348.0
#
#                      geometry
# 0  POINT (-74.04309 40.71941)
# 1   POINT (-74.0303 40.73594)
# 2  POINT (-74.02901 40.73672)
# 3   POINT (-74.04425 40.7276)
# 4  POINT (-74.06444 40.73101)

# %% [markdown]
# ### Write Station Points to PostGIS

# %%
station_gdf.to_postgis(
    name="jc_2025_stations",
    con=engine,
    if_exists="replace",
    index=False
)

# %% [markdown]
# ### Check Station Spatial Table

# %%
query = """
SELECT
    station_id,
    station_name,
    total_activity,
    ST_GeometryType(geometry) AS geometry_type,
    ST_SRID(geometry) AS srid
FROM jc_2025_stations
LIMIT 5;
"""

pd.read_sql(
    query,
    con=engine
)
# Out:
#   station_id                              station_name  total_activity  \
# 0      JC115                             Grove St PATH         92865.0
# 1      HB101  Hoboken Terminal - Hudson St & Hudson Pl         52602.0
# 2      JC009                             Hamilton Park         44658.0
# 3      HB106                      River St & Newark St         43602.0
# 4      JC066                              Newport PATH         41402.0
#
#   geometry_type  srid
# 0      ST_Point  4326
# 1      ST_Point  4326
# 2      ST_Point  4326
# 3      ST_Point  4326
# 4      ST_Point  4326

# %% [markdown]
# # Update Data for 2026

# %% [markdown]
# ### Imports

# %%
from pathlib import Path
from urllib.request import urlretrieve
from urllib.error import HTTPError, URLError
from zipfile import ZipFile

import sys
import os

sys.path.append(os.path.abspath('..'))
from utils import period_iterator, download_jersey_tripdata_zip_and_extract_to_local, remove_prefix

import shutil
import glob

# %% [markdown]
# ## Download and save the 2026 Citibike data

# %%
CITIBIKE_INDEX_URL = "https://s3.amazonaws.com/tripdata"
OUTPUT_DIR = "../data/citibike/"

# %%
PERIODS = period_iterator(year =["2026"], start_m=0, stop_m=6)
PERIODS
# Out:
# ['202601', '202602', '202603', '202604', '202605', '202606']

# %%
output_dir = Path(OUTPUT_DIR)
output_dir.mkdir(exist_ok=True)

download_jersey_tripdata_zip_and_extract_to_local(
    periods=PERIODS,
    base_url=CITIBIKE_INDEX_URL,
    local_path=output_dir
)
# Out:
# JC-202601-citibike-tripdata.zip  Extracted
# JC-202601-citibike-tripdata.zip removed.
# JC-202602-citibike-tripdata.csv.zip  Extracted
# JC-202602-citibike-tripdata.csv.zip removed.
# JC-202603-citibike-tripdata.csv.zip  Extracted
# JC-202603-citibike-tripdata.csv.zip removed.
# JC-202604-citibike-tripdata.zip  Extracted
# JC-202604-citibike-tripdata.zip removed.
# JC-202605-citibike-tripdata.csv.zip  Extracted
# JC-202605-citibike-tripdata.csv.zip removed.
# JC-202606-citibike-tripdata.csv.zip  Extracted
# JC-202606-citibike-tripdata.csv.zip removed.

# %%
shutil.rmtree(output_dir / "__MACOSX")

# %%
file_names = glob.glob(f'{output_dir}/*.csv')



dfs = []
cols = []
for file_name in file_names:
    df = pd.read_csv(file_name)
    print(df.columns, 2*"||",len(df.columns))

    cols.append(list(df.columns))
    dfs.append(df)
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual'],
#       dtype='str') |||| 13
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual'],
#       dtype='str') |||| 13
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual'],
#       dtype='str') |||| 13
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual'],
#       dtype='str') |||| 13
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual'],
#       dtype='str') |||| 13
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual'],
#       dtype='str') |||| 13

# %%
citibike26_df = pd.concat(dfs, ignore_index=True)
citibike26_df.head()
# Out:
#             ride_id  rideable_type               started_at  \
# 0  40FBC7AEEBB220EC  electric_bike  2026-01-11 15:01:01.954
# 1  47FB1CA65D3F7E0F  electric_bike  2026-01-16 11:49:41.364
# 2  BFB10DE1E40F3709  electric_bike  2026-01-07 19:55:41.424
# 3  F16B896495AAF618  electric_bike  2026-01-24 11:12:10.547
# 4  76D77D5F1D491B3C  electric_bike  2026-01-22 20:58:00.602
#
#                   ended_at                 start_station_name  \
# 0  2026-01-11 15:16:57.103  14 St Ferry - 14 St & Shipyard Ln
# 1  2026-01-16 11:58:27.291  14 St Ferry - 14 St & Shipyard Ln
# 2  2026-01-07 19:59:09.874   Church Sq Park - 5 St & Park Ave
# 3  2026-01-24 11:34:42.801                  Madison St & 1 St
# 4  2026-01-22 21:02:39.088                  Clinton St & 7 St
#
#   start_station_id          end_station_name end_station_id  start_lat  \
# 0            HB202  Pier 61 at Chelsea Piers        6233.04  40.752961
# 1            HB202         Madison St & 1 St          HB402  40.752961
# 2            HB601         Madison St & 1 St          HB402  40.742659
# 3            HB402         Madison St & 1 St          HB402  40.738790
# 4            HB303         Madison St & 1 St          HB402  40.745420
#
#    start_lng    end_lat   end_lng member_casual
# 0 -74.024353  40.746872 -74.00821        member
# 1 -74.024353  40.738790 -74.03930        member
# 2 -74.032233  40.738790 -74.03930        member
# 3 -74.039300  40.738790 -74.03930        member
# 4 -74.033320  40.738790 -74.03930        casual

# %%
citibike26_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 415739 entries, 0 to 415738
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             415739 non-null  str
#  1   rideable_type       415739 non-null  str
#  2   started_at          415739 non-null  str
#  3   ended_at            415739 non-null  str
#  4   start_station_name  415738 non-null  str
#  5   start_station_id    415738 non-null  str
#  6   end_station_name    413634 non-null  str
#  7   end_station_id      412883 non-null  str
#  8   start_lat           415738 non-null  float64
#  9   start_lng           415738 non-null  float64
#  10  end_lat             412897 non-null  float64
#  11  end_lng             412897 non-null  float64
#  12  member_casual       415739 non-null  str
# dtypes: float64(4), str(9)
# memory usage: 41.2 MB

# %%
citibike26_df.isna().sum()
# Out:
# ride_id                  0
# rideable_type            0
# started_at               0
# ended_at                 0
# start_station_name       1
# start_station_id         1
# end_station_name      2105
# end_station_id        2856
# start_lat                1
# start_lng                1
# end_lat               2842
# end_lng               2842
# member_casual            0
# dtype: int64

# %% [markdown]
# #### Converting the date columns to datetime format

# %%
# Cleaning the Data
citibike26_df["started_at"] = pd.to_datetime(
    citibike26_df["started_at"],
    errors="coerce"
)

citibike26_df["ended_at"] = pd.to_datetime(
    citibike26_df["ended_at"],
    errors="coerce"
)

# %%
citibike26_df["ride_date"] = citibike26_df["started_at"].dt.date

citibike26_df["ride_date"] = pd.to_datetime(
    citibike26_df["ride_date"],
    errors="coerce"
)

citibike26_df.head()
# Out:
#             ride_id  rideable_type              started_at  \
# 0  40FBC7AEEBB220EC  electric_bike 2026-01-11 15:01:01.954
# 1  47FB1CA65D3F7E0F  electric_bike 2026-01-16 11:49:41.364
# 2  BFB10DE1E40F3709  electric_bike 2026-01-07 19:55:41.424
# 3  F16B896495AAF618  electric_bike 2026-01-24 11:12:10.547
# 4  76D77D5F1D491B3C  electric_bike 2026-01-22 20:58:00.602
#
#                  ended_at                 start_station_name start_station_id  \
# 0 2026-01-11 15:16:57.103  14 St Ferry - 14 St & Shipyard Ln            HB202
# 1 2026-01-16 11:58:27.291  14 St Ferry - 14 St & Shipyard Ln            HB202
# 2 2026-01-07 19:59:09.874   Church Sq Park - 5 St & Park Ave            HB601
# 3 2026-01-24 11:34:42.801                  Madison St & 1 St            HB402
# 4 2026-01-22 21:02:39.088                  Clinton St & 7 St            HB303
#
#            end_station_name end_station_id  start_lat  start_lng    end_lat  \
# 0  Pier 61 at Chelsea Piers        6233.04  40.752961 -74.024353  40.746872
# 1         Madison St & 1 St          HB402  40.752961 -74.024353  40.738790
# 2         Madison St & 1 St          HB402  40.742659 -74.032233  40.738790
# 3         Madison St & 1 St          HB402  40.738790 -74.039300  40.738790
# 4         Madison St & 1 St          HB402  40.745420 -74.033320  40.738790
#
#     end_lng member_casual  ride_date
# 0 -74.00821        member 2026-01-11
# 1 -74.03930        member 2026-01-16
# 2 -74.03930        member 2026-01-07
# 3 -74.03930        member 2026-01-24
# 4 -74.03930        casual 2026-01-22

# %%
citibike26_df.to_csv("../data/JC/JC2026.csv", index = False)

# %% [markdown]
# ### Update the code to include the new data for 2026 and save it to a CSV file.

# %%
citibike_df = pd.concat([citibike_df, citibike26_df], ignore_index=True)
citibike_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1418443 entries, 0 to 1418442
# Data columns (total 14 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   ride_id             1418443 non-null  str
#  1   rideable_type       1418443 non-null  str
#  2   started_at          1418443 non-null  datetime64[us]
#  3   ended_at            1418443 non-null  datetime64[us]
#  4   start_station_name  1418439 non-null  str
#  5   start_station_id    1418439 non-null  str
#  6   end_station_name    1413103 non-null  str
#  7   end_station_id      1411190 non-null  str
#  8   start_lat           1418440 non-null  float64
#  9   start_lng           1418440 non-null  float64
#  10  end_lat             1412157 non-null  float64
#  11  end_lng             1412157 non-null  float64
#  12  member_casual       1418443 non-null  str
#  13  ride_date           1418443 non-null  datetime64[s]
# dtypes: datetime64[s](1), datetime64[us](2), float64(4), str(7)
# memory usage: 151.5 MB

# %%
citibike_df.isna().sum()
# Out:
# ride_id                  0
# rideable_type            0
# started_at               0
# ended_at                 0
# start_station_name       4
# start_station_id         4
# end_station_name      5340
# end_station_id        7253
# start_lat                3
# start_lng                3
# end_lat               6286
# end_lng               6286
# member_casual            0
# ride_date                0
# dtype: int64

# %%
citibike_df.to_csv("../data/JC/JC2025_2026.csv", index = False)

# %%
shutil.rmtree(output_dir)

# %% [markdown]
# ### Update `jersey_city` table with 2026 data in PostgreSQL

# %%
citibike26_df.to_sql(
    name="jersey_city",
    con=engine,
    if_exists="append",
    index=False,
    chunksize=50_000,
    method="multi"
)
# Out:
# 415739

# %% [markdown]
# ## Update weather data for 2026

# %%
import requests

# %%
lat = 40.7178
lng = -74.0431

start_date = "2026-01-01"
end_date = "2026-06-30"

url = "https://archive-api.open-meteo.com/v1/archive"

params = {
    "latitude": lat,
    "longitude": lng,
    "start_date": start_date,
    "end_date": end_date,
    "daily": [
        "temperature_2m_max",
        "temperature_2m_min",
        "temperature_2m_mean",
        "precipitation_sum",
        "rain_sum",
        "snowfall_sum",
        "wind_speed_10m_max"
    ],
    "timezone": "America/New_York"
}

response = requests.get(url, params=params)
response.raise_for_status()

data = response.json()

weather_daily = pd.DataFrame(data["daily"])
weather_daily["date"] = pd.to_datetime(weather_daily["time"])
weather_daily = weather_daily.drop(columns="time")

weather_daily.head()
# Out:
#    temperature_2m_max  temperature_2m_min  temperature_2m_mean  \
# 0                 0.7                -7.1                 -3.4
# 1                -1.3                -7.3                 -4.4
# 2                -0.7                -6.7                 -3.5
# 3                 1.0                -4.5                 -2.2
# 4                 0.9                -5.4                 -1.8
#
#    precipitation_sum  rain_sum  snowfall_sum  wind_speed_10m_max       date
# 0                1.1       0.0          0.77                25.1 2026-01-01
# 1                0.3       0.0          0.21                14.4 2026-01-02
# 2                0.0       0.0          0.00                10.3 2026-01-03
# 3                0.3       0.0          0.21                12.1 2026-01-04
# 4                0.8       0.0          0.56                12.6 2026-01-05

# %%
missing_values = (
    weather_daily
        .isna()
        .sum()
        .reset_index()
)

missing_values.columns = ["column", "missing_count"]
missing_values
# Out:
#                 column  missing_count
# 0   temperature_2m_max              0
# 1   temperature_2m_min              0
# 2  temperature_2m_mean              0
# 3    precipitation_sum              0
# 4             rain_sum              0
# 5         snowfall_sum              0
# 6   wind_speed_10m_max              0
# 7                 date              0

# %%
weather_daily = weather_daily.rename(
    columns={
        "temperature_2m_max": "temp_max",
        "temperature_2m_min": "temp_min",
        "temperature_2m_mean": "temp_mean"
    }
)

weather_daily.head()
# Out:
#    temp_max  temp_min  temp_mean  precipitation_sum  rain_sum  snowfall_sum  \
# 0       0.7      -7.1       -3.4                1.1       0.0          0.77
# 1      -1.3      -7.3       -4.4                0.3       0.0          0.21
# 2      -0.7      -6.7       -3.5                0.0       0.0          0.00
# 3       1.0      -4.5       -2.2                0.3       0.0          0.21
# 4       0.9      -5.4       -1.8                0.8       0.0          0.56
#
#    wind_speed_10m_max       date
# 0                25.1 2026-01-01
# 1                14.4 2026-01-02
# 2                10.3 2026-01-03
# 3                12.1 2026-01-04
# 4                12.6 2026-01-05

# %% [markdown]
# ## Update weather data with 2026 data in the database

# %%
weather_daily.to_sql(
    name="jersey_weather",
    con=engine,
    if_exists="append",
    index=False
)
# Out:
# 181

# %% [markdown]
# ## Check if new stations are available in the 2026 data

# %% [markdown]
# ### Get citibike data for 2025 and 2026, and check for new stations in 2026 that are not present in 2025

# %%
citibike26_df = pd.read_csv("../data/JC/JC2026.csv")

start_stations26 =  citibike26_df[
    [
        "start_station_id",
        "start_station_name",
        "start_lat",
        "start_lng"
    ]
].copy()

start_stations26 = start_stations26.rename(
    columns={
        "start_station_id": "station_id",
        "start_station_name": "station_name",
        "start_lat": "lat",
        "start_lng": "lng"
    }
)

end_stations26 =  citibike26_df[
    [
        "end_station_id",
        "end_station_name",
        "end_lat",
        "end_lng"
    ]
].copy()

end_stations26 = end_stations26.rename(
    columns={
        "end_station_id": "station_id",
        "end_station_name": "station_name",
        "end_lat": "lat",
        "end_lng": "lng"
    }
)

stations26 = pd.concat([start_stations26, end_stations26], ignore_index=True)

stations26 = stations26.drop_duplicates(subset=["station_id", "station_name", "lat", "lng"])
stations26 = stations26.dropna(subset=["station_id", "station_name", "lat", "lng"])

# %%
citibike25_df = pd.read_csv("../data/JC/JC2025.csv")

start_stations25 =  citibike25_df[
    [
        "start_station_id",
        "start_station_name",
        "start_lat",
        "start_lng"
    ]
].copy()

start_stations25 = start_stations25.rename(
    columns={
        "start_station_id": "station_id",
        "start_station_name": "station_name",
        "start_lat": "lat",
        "start_lng": "lng"
    }
)

end_stations25 =  citibike25_df[
    [
        "end_station_id",
        "end_station_name",
        "end_lat",
        "end_lng"
    ]
].copy()

end_stations25 = end_stations25.rename(
    columns={
        "end_station_id": "station_id",
        "end_station_name": "station_name",
        "end_lat": "lat",
        "end_lng": "lng"
    }
)

stations25 = pd.concat([start_stations25, end_stations25], ignore_index=True)

stations25 = stations25.drop_duplicates(subset=["station_id", "station_name", "lat", "lng"])
stations25 = stations25.dropna(subset=["station_id", "station_name", "lat", "lng"])

# %%
new_stations = stations26["station_id"][~stations26["station_id"].isin(stations25["station_id"])]
print(new_stations.head())
print(new_stations.shape)
# Out:
# 102413      JC149
# 102419      JC148
# 103124      HB410
# 419978    6122.09
# 425182    6659.09
# Name: station_id, dtype: str
# (76,)

# %% [markdown]
# #### checking if a sample of new stations in 2026 is present in 2025 data

# %%
sample_id = new_stations.iloc[0]
print(f"One of new stations in 2026 that is not present in 2025 is: {sample_id}")    
# Test with the sample_id
is_present = sample_id in stations25['station_id'].values
print(f"Is {sample_id} in 2025 data?: {is_present}")
# Out:
# One of new stations in 2026 that is not present in 2025 is: JC149
# Is JC149 in 2025 data?: False

# %% [markdown]
# ### There are new stations in 2026 that are not present in 2025. This indicates that the station data has changed between the two years, and we need to account for these new stations when analyzing the data.
# - Keep the combined(2025&2026) data name as 'citibike_df' and rerun "Create Station Summary" part
# - Convert Station Summary to GeoDataFrame
# - Write Points to PostGIS

# %%
citibike_df = pd.concat([citibike25_df, citibike26_df], ignore_index=True)
citibike_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1418443 entries, 0 to 1418442
# Data columns (total 14 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   ride_id             1418443 non-null  str
#  1   rideable_type       1418443 non-null  str
#  2   started_at          1418443 non-null  str
#  3   ended_at            1418443 non-null  str
#  4   start_station_name  1418439 non-null  str
#  5   start_station_id    1418439 non-null  str
#  6   end_station_name    1413103 non-null  str
#  7   end_station_id      1411190 non-null  str
#  8   start_lat           1418440 non-null  float64
#  9   start_lng           1418440 non-null  float64
#  10  end_lat             1412157 non-null  float64
#  11  end_lng             1412157 non-null  float64
#  12  member_casual       1418443 non-null  str
#  13  ride_date           415739 non-null   str
# dtypes: float64(4), str(10)
# memory usage: 151.5 MB

# %% [markdown]
# #### Write Combined Geodata Points to PostGIS

# %%
station_gdf.to_postgis(
    name="jc_2025_2026_stations",
    con=engine,
    if_exists="replace",
    index=False
)

# %% [markdown]
# # SQLAlchemy

# %% [markdown]
# ### List tables

# %%
query = """
SELECT table_name
FROM information_schema.tables
WHERE table_schema = 'public'
ORDER BY table_name;
"""

pd.read_sql(
    query,
    con=engine
)
# Out:
#                   table_name
# 0          geography_columns
# 1           geometry_columns
# 2      jc_2025_2026_stations
# 3           jc_2025_stations
# 4                jersey_city
# 5  jersey_city_neighborhoods
# 6             jersey_weather
# 7                     people
# 8            spatial_ref_sys

# %% [markdown]
# ### Count Rows for each table

# %%
query = """
    SELECT 'jersey_city' AS table_name, COUNT(*) AS row_count FROM jersey_city
    UNION ALL
    SELECT 'jersey_weather' AS table_name, COUNT(*) AS row_count FROM jersey_weather
    UNION ALL
    SELECT 'jersey_city_neighborhoods' AS table_name, COUNT(*) AS row_count FROM jersey_city_neighborhoods
    UNION ALL
    SELECT 'jc_2025_stations' AS table_name, COUNT(*) AS row_count FROM jc_2025_stations;
"""

pd.read_sql(
    query,
    con=engine
)
# Out:
#                   table_name  row_count
# 0                jersey_city    1002704
# 1             jersey_weather        365
# 2  jersey_city_neighborhoods         53
# 3           jc_2025_stations        488

# %% [markdown]
# ### Daily Ride Volume

# %%
query = """
    SELECT
        started_at::date AS ride_date,
        COUNT(*) AS number_of_rides
    FROM jersey_city
    GROUP BY started_at::date
    ORDER BY ride_date;
"""

daily_rides_sql = pd.read_sql(
    query,
    con=engine
)

daily_rides_sql.head()
# Out:
#     ride_date  number_of_rides
# 0  2024-12-31                2
# 1  2025-01-01             1179
# 2  2025-01-02             1711
# 3  2025-01-03             1771
# 4  2025-01-04             1337

# %% [markdown]
# ### Join Citi Bike and Weather

# %%
query = """
SELECT
    c.started_at::date AS ride_date,
    COUNT(*) AS number_of_rides,
    w."2m_mean",
    w.precipitation_sum,
    w.rain_sum,
    w.snowfall_sum,
    w.wind_speed_10m_max
FROM jersey_city AS c
LEFT JOIN jersey_weather AS w
    ON c.started_at::date = w.date::date
GROUP BY
    c.started_at::date,
    w."2m_mean",
    w.precipitation_sum,
    w.rain_sum,
    w.snowfall_sum,
    w.wind_speed_10m_max
ORDER BY ride_date;
"""

bike_weather_sql = pd.read_sql(
    query,
    con=engine
)

bike_weather_sql.head()
# Out:
#     ride_date  number_of_rides  2m_mean  precipitation_sum  rain_sum  \
# 0  2024-12-31                2      NaN                NaN       NaN
# 1  2025-01-01             1179      NaN                NaN       NaN
# 2  2025-01-02             1711      NaN                NaN       NaN
# 3  2025-01-03             1771      NaN                NaN       NaN
# 4  2025-01-04             1337      NaN                NaN       NaN
#
#    snowfall_sum  wind_speed_10m_max
# 0           NaN                 NaN
# 1           NaN                 NaN
# 2           NaN                 NaN
# 3           NaN                 NaN
# 4           NaN                 NaN

# %% [markdown]
# ### Spatial Join in SQL: Stations to Neighborhoods

# %%
#| echo: true

query = """
SELECT
    s.station_id,
    s.station_name,
    s.total_departures,
    s.total_arrivals,
    s.total_activity,
    s.net_departures,
    n.neighborhood
FROM jc_2025_2026_stations AS s
JOIN jersey_city_neighborhoods AS n
    ON ST_Within(s.geometry, n.geometry)
ORDER BY s.total_activity DESC;
"""

station_neighborhood_sql = pd.read_sql(
    query,
    con=engine
)

station_neighborhood_sql.head()
# Out:
#   station_id          station_name  total_departures  total_arrivals  \
# 0      JC115         Grove St PATH           64280.0         67171.0
# 1      JC009         Hamilton Park           31305.0         31335.0
# 2      JC109  Bergen Ave & Sip Ave           30430.0         30082.0
# 3      JC116           Exchange Pl           28236.0         28198.0
# 4      JC066          Newport PATH           27850.0         27782.0
#
#    total_activity  net_departures    neighborhood
# 0        131451.0         -2891.0  Van Vorst Park
# 1         62640.0           -30.0   Hamilton Park
# 2         60512.0           348.0  Journal Square
# 3         56434.0            38.0  Exchange Place
# 4         55632.0            68.0         Newport

# %% [markdown]
# ### Aggregate Station Activity by Neighborhood in SQL

# %%
query = """
SELECT
    n.neighborhood,
    COUNT(DISTINCT s.station_id) AS number_of_stations,
    SUM(s.total_departures) AS total_departures,
    SUM(s.total_arrivals) AS total_arrivals,
    SUM(s.total_activity) AS total_activity,
    SUM(s.net_departures) AS net_departures,
    SUM(s.total_activity)::numeric / NULLIF(COUNT(DISTINCT s.station_id), 0) AS avg_activity_per_station
FROM jersey_city_neighborhoods AS n
LEFT JOIN jc_2025_2026_stations AS s
    ON ST_Within(s.geometry, n.geometry)
GROUP BY n.neighborhood
ORDER BY total_activity DESC;
"""

neighborhood_activity_sql = pd.read_sql(
    query,
    con=engine
)

neighborhood_activity_sql.tail()
# Out:
#          neighborhood  number_of_stations  total_departures  total_arrivals  \
# 46          West Side                   2            3919.0          3901.0
# 47            Bayside                   2            1090.0          1114.0
# 48      State College                   3            1096.0          1096.0
# 49       Port Liberte                   1             431.0           430.0
# 50  Our Lady of Mercy                   1             223.0           245.0
#
#     total_activity  net_departures  avg_activity_per_station
# 46          7820.0            18.0               3910.000000
# 47          2204.0           -24.0               1102.000000
# 48          2192.0             0.0                730.666667
# 49           861.0             1.0                861.000000
# 50           468.0           -22.0                468.000000

# %% [markdown]
# ### Create Spatial Indexes

# %%
with engine.begin() as connection:
    connection.execute(text("""
        CREATE INDEX IF NOT EXISTS idx_jc_2025_2026_stations_geom
        ON jc_2025_2026_stations
        USING GIST (geometry);
    """))

    connection.execute(text("""
        CREATE INDEX IF NOT EXISTS idx_jersey_city_neighborhoods_geom
        ON jersey_city_neighborhoods
        USING GIST (geometry);
    """))

    connection.execute(text("""
        CREATE INDEX IF NOT EXISTS idx_jc_2025_2026_started_at
        ON jersey_city(started_at);
    """))

    connection.execute(text("""
        CREATE INDEX IF NOT EXISTS idx_weather_date
        ON jersey_weather (date);
    """))

# %% [markdown]
# #### Remove Duplicate Rows from Jersey City Table

# %%
remove_duplicates = """
DELETE FROM jersey_city
WHERE ctid IN (
    SELECT ctid
    FROM (
        SELECT ctid,
               ROW_NUMBER() OVER (PARTITION BY ride_id ORDER BY ctid) as rn
        FROM jersey_city
    ) t
    WHERE t.rn > 1
);
"""

with engine.begin() as connection:
    connection.execute(text(remove_duplicates))

# %% [markdown]
# ### Create Materialized View with SQLAlchemy

# %%
from sqlalchemy import text

# %%
create_tableau_materialized_view_sql = """
DROP MATERIALIZED VIEW IF EXISTS mv_tableau_citibike_dashboard;

CREATE MATERIALIZED VIEW mv_tableau_citibike_dashboard AS
WITH ride_base AS (
    SELECT
        c.ride_id,
        c.rideable_type,
        c.member_casual,

        c.started_at,
        c.ended_at,
        c.started_at::date AS ride_date,

        EXTRACT(YEAR FROM c.started_at)::int AS ride_year,
        EXTRACT(QUARTER FROM c.started_at)::int AS ride_quarter,
        EXTRACT(MONTH FROM c.started_at)::int AS ride_month,
        TO_CHAR(c.started_at, 'Month') AS ride_month_name,
        TO_CHAR(c.started_at, 'Day') AS ride_day_of_week,
        EXTRACT(ISODOW FROM c.started_at)::int AS ride_day_number,
        EXTRACT(HOUR FROM c.started_at)::int AS ride_hour,

        CASE
            WHEN EXTRACT(ISODOW FROM c.started_at) IN (6, 7)
                THEN 'Weekend'
            ELSE 'Weekday'
        END AS weekday_type,

        EXTRACT(EPOCH FROM (c.ended_at - c.started_at)) / 60.0 AS ride_duration_minutes,

        c.start_station_id,
        c.start_station_name,
        c.end_station_id,
        c.end_station_name,

        c.start_lat,
        c.start_lng,
        c.end_lat,
        c.end_lng,

        ST_SetSRID(
            ST_MakePoint(c.start_lng, c.start_lat),
            4326
        ) AS start_geom,

        ST_SetSRID(
            ST_MakePoint(c.end_lng, c.end_lat),
            4326
        ) AS end_geom

    FROM jersey_city AS c
    WHERE
        c.ride_id IS NOT NULL
        AND c.started_at IS NOT NULL
        AND c.ended_at IS NOT NULL
        AND c.ended_at > c.started_at
        AND c.start_lat IS NOT NULL
        AND c.start_lng IS NOT NULL
        AND c.end_lat IS NOT NULL
        AND c.end_lng IS NOT NULL
)

SELECT
    r.ride_id,
    r.rideable_type,
    r.member_casual,

    r.started_at,
    r.ended_at,
    r.ride_date,
    r.ride_year,
    r.ride_quarter,
    r.ride_month,
    TRIM(r.ride_month_name) AS ride_month_name,
    TRIM(r.ride_day_of_week) AS ride_day_of_week,
    r.ride_day_number,
    r.ride_hour,
    r.weekday_type,

    r.ride_duration_minutes,

    r.start_station_id,
    r.start_station_name,
    r.end_station_id,
    r.end_station_name,

    r.start_lat,
    r.start_lng,
    r.end_lat,
    r.end_lng,

    start_n.neighborhood AS start_neighborhood,
    end_n.neighborhood AS end_neighborhood,
    
    CASE
        WHEN ST_Within(r.start_geom, start_n.geometry)
            THEN start_n.geometry
        ELSE NULL
    END AS start_neighborhood_geom,

    CASE
        WHEN ST_Within(r.end_geom, end_n.geometry)
            THEN end_n.geometry
        ELSE NULL
    END AS end_neighborhood_geom,

    ST_Distance(
        r.start_geom::geography,
        r.end_geom::geography
    ) / 1000.0 AS distance_km,

    CASE
        WHEN ST_Distance(r.start_geom::geography, r.end_geom::geography) / 1000.0 < 1
            THEN 'Short'
        WHEN ST_Distance(r.start_geom::geography, r.end_geom::geography) / 1000.0 < 3
            THEN 'Medium'
        ELSE 'Long'
    END AS distance_group,

    CASE
        WHEN r.ride_duration_minutes < 10
            THEN 'Short'
        WHEN r.ride_duration_minutes < 30
            THEN 'Medium'
        ELSE 'Long'
    END AS duration_group,

    w.temp_max,
    w.temp_min,
    w.temp_mean,
    w.precipitation_sum,
    w.rain_sum,
    w.snowfall_sum,
    w.wind_speed_10m_max,

    CASE
        WHEN w.precipitation_sum > 0
            THEN 'Precipitation'
        ELSE 'No Precipitation'
    END AS precipitation_flag,

    CASE
        WHEN w.temp_mean < 0
            THEN 'Freezing'
        WHEN w.temp_mean < 10
            THEN 'Cold'
        WHEN w.temp_mean < 20
            THEN 'Mild'
        ELSE 'Warm'
    END AS temperature_group

FROM ride_base AS r

LEFT JOIN jersey_weather AS w
    ON r.ride_date = w.date::date

LEFT JOIN jersey_city_neighborhoods AS start_n
    ON ST_Within(r.start_geom, start_n.geometry)

LEFT JOIN jersey_city_neighborhoods AS end_n
    ON ST_Within(r.end_geom, end_n.geometry);
"""

# %%
with engine.begin() as connection:
    connection.execute(text(create_tableau_materialized_view_sql))

# %% [markdown]
# #### Check the Materialized View

# %%
query = """SELECT 
start_neighborhood_geom,
end_neighborhood_geom
FROM mv_tableau_citibike_dashboard
LIMIT 10;
"""

pd.read_sql(
    query,
    con=engine
)
# Out:
#                              start_neighborhood_geom  \
# 0  0103000020E61000000100000014000000CF81DFC97C84...
# 1  0103000020E61000000100000014000000CF81DFC97C84...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                                end_neighborhood_geom
# 0  0103000020E61000000100000016000000EDA4E6FBDF85...
# 1  0103000020E61000000100000016000000EDA4E6FBDF85...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN

# %%
query = """SELECT *
FROM mv_tableau_citibike_dashboard
LIMIT 10;
"""

pd.read_sql(
    query,
    con=engine
)
# Out:
#             ride_id  rideable_type member_casual              started_at  \
# 0  9F734BE1BFC45FF4  electric_bike        member 2025-11-18 18:34:14.943
# 1  B6C773B13AC0E465   classic_bike        member 2025-11-26 16:29:15.513
# 2  C300465AA158280F  electric_bike        member 2025-11-04 22:31:58.010
# 3  31A424FC97C8AAFB   classic_bike        member 2025-11-08 06:51:57.424
# 4  08C5EA04CB1FDC57   classic_bike        member 2025-11-24 20:31:21.758
# 5  FE738136C74EA7C0  electric_bike        member 2025-11-23 14:39:45.031
# 6  EFD5AB3E138908E4  electric_bike        member 2025-11-19 21:08:33.665
# 7  A45C71BC39881445  electric_bike        member 2025-11-11 15:29:51.785
# 8  33FE83F576FDA580  electric_bike        member 2025-11-08 13:11:03.012
# 9  29D92C83FFD009F2  electric_bike        member 2025-11-14 18:39:54.678
#
#                  ended_at   ride_date  ride_year  ride_quarter  ride_month  \
# 0 2025-11-18 18:47:33.391  2025-11-18       2025             4          11
# 1 2025-11-26 16:43:45.235  2025-11-26       2025             4          11
# 2 2025-11-04 22:38:57.017  2025-11-04       2025             4          11
# 3 2025-11-08 06:57:45.627  2025-11-08       2025             4          11
# 4 2025-11-24 20:38:01.261  2025-11-24       2025             4          11
# 5 2025-11-23 14:43:32.044  2025-11-23       2025             4          11
# 6 2025-11-19 21:14:22.866  2025-11-19       2025             4          11
# 7 2025-11-11 15:33:44.683  2025-11-11       2025             4          11
# 8 2025-11-08 13:15:13.476  2025-11-08       2025             4          11
# 9 2025-11-14 18:44:18.044  2025-11-14       2025             4          11
#
#   ride_month_name  ... duration_group  temp_max  temp_min temp_mean  \
# 0        November  ...         Medium       7.9       0.9       4.5
# 1        November  ...         Medium      15.4      10.9      13.2
# 2        November  ...          Short      14.9       8.1      10.9
# 3        November  ...          Short      18.5      11.9      14.2
# 4        November  ...          Short      11.4       4.2       6.8
# 5        November  ...          Short       7.7      -0.9       3.8
# 6        November  ...          Short       8.2       2.0       4.8
# 7        November  ...          Short       4.3       0.8       2.4
# 8        November  ...          Short      18.5      11.9      14.2
# 9        November  ...          Short      10.1       2.9       6.3
#
#    precipitation_sum rain_sum snowfall_sum wind_speed_10m_max  \
# 0                0.0      0.0         0.00               16.1
# 1                4.6      4.6         0.00               17.6
# 2                0.0      0.0         0.00               23.1
# 3                4.8      4.8         0.00               15.2
# 4                0.0      0.0         0.00               13.5
# 5                0.0      0.0         0.00               12.2
# 6                4.6      3.8         0.56                8.7
# 7                0.5      0.0         0.35               28.2
# 8                4.8      4.8         0.00               15.2
# 9                0.0      0.0         0.00               16.5
#
#   precipitation_flag  temperature_group
# 0   No Precipitation               Cold
# 1      Precipitation               Mild
# 2   No Precipitation               Mild
# 3      Precipitation               Mild
# 4   No Precipitation               Cold
# 5   No Precipitation               Cold
# 6      Precipitation               Cold
# 7      Precipitation               Cold
# 8      Precipitation               Mild
# 9   No Precipitation               Cold
#
# [10 rows x 39 columns]

# %% [markdown]
# #### Check Number of Rows

# %%
query = """
SELECT
    COUNT(*) AS number_of_rows
FROM mv_tableau_citibike_dashboard;
"""

pd.read_sql(
    query,
    con=engine
)
# Out:
#    number_of_rows
# 0         1412129

# %% [markdown]
# #### Check Data Quality

# %%
query = """
SELECT
    COUNT(*) AS total_rides,

    COUNT(temp_mean) AS rides_with_weather,
    COUNT(*) - COUNT(temp_mean) AS rides_missing_weather,

    COUNT(start_neighborhood) AS rides_with_start_neighborhood,
    COUNT(*) - COUNT(start_neighborhood) AS rides_missing_start_neighborhood,

    COUNT(end_neighborhood) AS rides_with_end_neighborhood,
    COUNT(*) - COUNT(end_neighborhood) AS rides_missing_end_neighborhood,

    COUNT(distance_km) AS rides_with_distance,
    COUNT(*) - COUNT(distance_km) AS rides_missing_distance
FROM mv_tableau_citibike_dashboard;
"""

pd.read_sql(
    query,
    con=engine
)
# Out:
#    total_rides  rides_with_weather  rides_missing_weather  \
# 0      1412129             1412127                      2
#
#    rides_with_start_neighborhood  rides_missing_start_neighborhood  \
# 0                         773769                            638360
#
#    rides_with_end_neighborhood  rides_missing_end_neighborhood  \
# 0                       767452                          644677
#
#    rides_with_distance  rides_missing_distance
# 0              1412129                       0

# %% [markdown]
# #### Create Indexes on the Materialized View

# %%
with engine.begin() as connection:
    connection.execute(text("""
        CREATE UNIQUE INDEX IF NOT EXISTS idx_mv_tableau_ride_id
        ON mv_tableau_citibike_dashboard (ride_id);
    """))

    connection.execute(text("""
        CREATE INDEX IF NOT EXISTS idx_mv_tableau_ride_date
        ON mv_tableau_citibike_dashboard (ride_date);
    """))

    connection.execute(text("""
        CREATE INDEX IF NOT EXISTS idx_mv_tableau_ride_month
        ON mv_tableau_citibike_dashboard (ride_year, ride_month);
    """))

    connection.execute(text("""
        CREATE INDEX IF NOT EXISTS idx_mv_tableau_ride_hour
        ON mv_tableau_citibike_dashboard (ride_hour);
    """))

    connection.execute(text("""
        CREATE INDEX IF NOT EXISTS idx_mv_tableau_member_casual
        ON mv_tableau_citibike_dashboard (member_casual);
    """))

    connection.execute(text("""
        CREATE INDEX IF NOT EXISTS idx_mv_tableau_rideable_type
        ON mv_tableau_citibike_dashboard (rideable_type);
    """))

    connection.execute(text("""
        CREATE INDEX IF NOT EXISTS idx_mv_tableau_start_station
        ON mv_tableau_citibike_dashboard (start_station_name);
    """))

    connection.execute(text("""
        CREATE INDEX IF NOT EXISTS idx_mv_tableau_end_station
        ON mv_tableau_citibike_dashboard (end_station_name);
    """))

    connection.execute(text("""
        CREATE INDEX IF NOT EXISTS idx_mv_tableau_start_neighborhood
        ON mv_tableau_citibike_dashboard (start_neighborhood);
    """))

    connection.execute(text("""
        CREATE INDEX IF NOT EXISTS idx_mv_tableau_end_neighborhood
        ON mv_tableau_citibike_dashboard (end_neighborhood);
    """))

# %% [markdown]
# #### Refresh Materialized View

# %%
# with engine.begin() as connection:
#     connection.execute(
#         text("REFRESH MATERIALIZED VIEW mv_tableau_citibike_dashboard;")
#     )

with engine.begin() as connection:
    connection.execute(
        text("REFRESH MATERIALIZED VIEW CONCURRENTLY mv_tableau_citibike_dashboard;")
    )

# %% [markdown]
# #### Create Helper Function to Refresh the Dashboard View
# Instead of writing the refresh code every time, we can create a small helper function.

# %%
def refresh_tableau_dashboard_view(engine, concurrently=False):
    if concurrently:
        refresh_sql = """
        REFRESH MATERIALIZED VIEW CONCURRENTLY mv_tableau_citibike_dashboard;
        """
    else:
        refresh_sql = """
        REFRESH MATERIALIZED VIEW mv_tableau_citibike_dashboard;
        """

    with engine.begin() as connection:
        connection.execute(text(refresh_sql))

# %%
refresh_tableau_dashboard_view(
    engine=engine,
    concurrently=True
)

# %% [markdown]
# #### Preview Fields for Tableau

# %%
query = """
SELECT
    ride_id,
    ride_date,
    ride_month_name,
    ride_day_of_week,
    weekday_type,
    ride_hour,
    rideable_type,
    member_casual,
    start_station_name,
    end_station_name,
    start_neighborhood,
    end_neighborhood,
    ride_duration_minutes,
    duration_group,
    distance_km,
    distance_group,
    temp_mean,
    temperature_group,
    precipitation_sum,
    precipitation_flag,
    rain_sum,
    snowfall_sum,
    wind_speed_10m_max
FROM mv_tableau_citibike_dashboard
LIMIT 10;
"""

pd.read_sql(
    query,
    con=engine
)
# Out:
#             ride_id   ride_date ride_month_name ride_day_of_week weekday_type  \
# 0  019A1A110CAAE4AB  2025-10-19         October           Sunday      Weekend
# 1  9B6F9FB1DFD29441  2025-10-19         October           Sunday      Weekend
# 2  439D5268B8377291  2025-10-19         October           Sunday      Weekend
# 3  66672C87CFFE21AD  2025-10-19         October           Sunday      Weekend
# 4  4993780754AE96D6  2025-10-19         October           Sunday      Weekend
# 5  AA0373F04D0A1A2F  2025-10-19         October           Sunday      Weekend
# 6  CDB9BDBA32F62391  2025-10-19         October           Sunday      Weekend
# 7  2FE3CD5AC7514A85  2025-10-19         October           Sunday      Weekend
# 8  45C457041027D01F  2025-10-19         October           Sunday      Weekend
# 9  D2EB92CF4102C8A2  2025-10-19         October           Sunday      Weekend
#
#    ride_hour  rideable_type member_casual            start_station_name  \
# 0         13  electric_bike        casual  Communipaw Ave & Pacific Ave
# 1         20  electric_bike        member                     City Hall
# 2         19  electric_bike        casual               River St & 1 St
# 3          0  electric_bike        member         Baldwin at Montgomery
# 4         15   classic_bike        member               4 St & Grand St
# 5         20  electric_bike        casual          8 St & Washington St
# 6         15   classic_bike        member               4 St & Grand St
# 7          4   classic_bike        casual         11 St & Washington St
# 8         15   classic_bike        member               4 St & Grand St
# 9         12  electric_bike        member              7 St & Monroe St
#
#                    end_station_name  ... duration_group distance_km  \
# 0                Liberty Light Rail  ...           Long    0.570070
# 1      Communipaw Ave & Pacific Ave  ...          Short    1.723966
# 2              12 St & Sinatra Dr N  ...          Short    1.542102
# 3              Bergen Ave & Sip Ave  ...          Short    0.816464
# 4                   6 St & Grand St  ...          Short    0.243153
# 5              12 St & Sinatra Dr N  ...          Short    0.622738
# 6                   6 St & Grand St  ...          Short    0.243153
# 7  City Hall - Washington St & 1 St  ...          Short    1.438623
# 8                   6 St & Grand St  ...          Short    0.243153
# 9                   6 St & Grand St  ...          Short    0.369128
#
#    distance_group temp_mean  temperature_group precipitation_sum  \
# 0           Short      15.9               Mild               0.0
# 1          Medium      15.9               Mild               0.0
# 2          Medium      15.9               Mild               0.0
# 3           Short      15.9               Mild               0.0
# 4           Short      15.9               Mild               0.0
# 5           Short      15.9               Mild               0.0
# 6           Short      15.9               Mild               0.0
# 7          Medium      15.9               Mild               0.0
# 8           Short      15.9               Mild               0.0
# 9           Short      15.9               Mild               0.0
#
#    precipitation_flag rain_sum  snowfall_sum wind_speed_10m_max
# 0    No Precipitation      0.0           0.0               20.4
# 1    No Precipitation      0.0           0.0               20.4
# 2    No Precipitation      0.0           0.0               20.4
# 3    No Precipitation      0.0           0.0               20.4
# 4    No Precipitation      0.0           0.0               20.4
# 5    No Precipitation      0.0           0.0               20.4
# 6    No Precipitation      0.0           0.0               20.4
# 7    No Precipitation      0.0           0.0               20.4
# 8    No Precipitation      0.0           0.0               20.4
# 9    No Precipitation      0.0           0.0               20.4
#
# [10 rows x 23 columns]
